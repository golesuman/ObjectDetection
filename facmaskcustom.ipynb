# %% [markdown]
# <a href="https://colab.research.google.com/github/golesuman/ObjectDetection/blob/main/facmaskcustom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="SLDIywqFskE8jMc06PsC")
project = rf.workspace("suman-gole").project("facemask-5tq1l")
dataset = project.version(2).download("yolov5")
# Out:
# ...
#      |████████████████████████████████| 145 kB 7.9 MB/s
# ...
#      |████████████████████████████████| 178 kB 40.4 MB/s
# ...
#      |████████████████████████████████| 596 kB 39.2 MB/s
# ...
#      |████████████████████████████████| 67 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 138 kB 46.4 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 33.9 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=50a4740724fd20c34bc5f8dc56f2efbdaf9d4dbeda5db8148f076ee8bcad647b
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.7
#     Uninstalling pyparsing-3.0.7:
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
from yolov5 import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v6.1-32-gc13d4ce torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 39.8/78.2 GB disk)

# %%
# !python train.py --img 640 --batch 2 --epochs 30 --data /content/facemask-2/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/facemask-2/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=2, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.1-32-gc13d4ce torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/facemask.mp4
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/facemask.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-32-gc13d4ce torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/420) /content/facemask.mp4: 640x384 1 mask, Done. (0.029s)
# video 1/1 (2/420) /content/facemask.mp4: 640x384 1 mask, Done. (0.028s)
# video 1/1 (3/420) /content/facemask.mp4: 640x384 1 mask, Done. (0.028s)
# video 1/1 (4/420) /content/facemask.mp4: 640x384 1 mask, Done. (0.028s)
# ...

# %%
# !python detect.py --weights /content/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/chinesemask.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# video 1/1 (2095/7092) /content/drive/MyDrive/chinesemask.mp4: 384x640 Done. (0.018s)
# video 1/1 (2096/7092) /content/drive/MyDrive/chinesemask.mp4: 384x640 Done. (0.018s)
# video 1/1 (2097/7092) /content/drive/MyDrive/chinesemask.mp4: 384x640 1 mask, Done. (0.018s)
# video 1/1 (2098/7092) /content/drive/MyDrive/chinesemask.mp4: 384x640 Done. (0.018s)
# video 1/1 (2099/7092) /content/drive/MyDrive/chinesemask.mp4: 384x640 Done. (0.018s)
# video 1/1 (2100/7092) /content/drive/MyDrive/chinesemask.mp4: 384x640 Done. (0.018s)
# video 1/1 (2101/7092) /content/drive/MyDrive/chinesemask.mp4: 384x640 1 mask, Done. (0.018s)
# video 1/1 (2102/7092) /content/drive/MyDrive/chinesemask.mp4: 384x640 Done. (0.018s)
# video 1/1 (2103/7092) /content/drive/MyDrive/chinesemask.mp4: 384x640 Done. (0.018s)
# video 1/1 (2104/7092) /content/drive/MyDrive/chinesemask.mp4: 384x640 Done. (0.018s)
# ...

# %%
# !python detect.py --weights /content/best.pt  --source /content/nomaskface.mp4
# Out:
# detect: weights=['/content/best.pt'], source=/content/nomaskface.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-32-gc13d4ce torch 1.10.0+cu111 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model Summary: 213 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/128) /content/nomaskface.mp4: 384x640 Done. (0.028s)
# video 1/1 (2/128) /content/nomaskface.mp4: 384x640 Done. (0.028s)
# video 1/1 (3/128) /content/nomaskface.mp4: 384x640 Done. (0.028s)
# video 1/1 (4/128) /content/nomaskface.mp4: 384x640 Done. (0.027s)
# video 1/1 (5/128) /content/nomaskface.mp4: 384x640 Done. (0.027s)
# ...
